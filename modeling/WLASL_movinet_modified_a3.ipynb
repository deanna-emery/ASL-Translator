# %%
#### DO NOT RUN THIS CODE IN THE NOTEBOOK - copy paste into terminal in the HOME directory!

# git clone https://github.com/tensorflow/models.git

# %%
 # !pip install s3fs -q
 # !pip install tensorflow_hub -q
 # !pip install tensorflow_datasets -q
 # !pip install pycocotools -q
 # !pip install gin-config -q
 # !pip install immutabledict -q
 # !pip install sentencepiece -q
 # !pip install transformers -q
 # !pip install -r official/projects/movinet/requirements.txt -q

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import configparser

config = configparser.ConfigParser()
config.read('/home/ec2-user/.aws/credentials')
# Out:
# ['/home/ec2-user/.aws/credentials']

# %%
# AWS credentials and S3 settings
aws_access_key_id = config["default"]['aws_access_key_id']
aws_secret_access_key = config["default"]['aws_secret_access_key']
bucket_name = 'asl-capstone'
s3_URI = 's3://asl-capstone/'

# %%
import s3fs
fs = s3fs.S3FileSystem(key=aws_access_key_id, secret=aws_secret_access_key)

import boto3
s3 = boto3.client('s3',aws_access_key_id = aws_access_key_id, aws_secret_access_key = aws_secret_access_key,
                  region_name = 'us-west-2')

# %%
import tensorflow as tf, tf_keras
import tensorflow_hub as hub
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import os
import requests
from typing import List, Tuple
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

tf.keras.backend.clear_session()
# Out:
# 2023-11-27 18:09:42.585670: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 18:09:43.300708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %cd /home/ec2-user/models
# Out:
# /home/ec2-user/models

# %%
pwd
# Out:
# '/home/ec2-user/models'

# %%
# # !wget https://storage.googleapis.com/tf_model_garden/vision/movinet/movinet_a0_base.tar.gz
# !wget https://storage.googleapis.com/tf_model_garden/vision/movinet/movinet_a3_base.tar.gz
# # !wget https://storage.googleapis.com/tf_model_garden/vision/movinet/movinet_a5_base.tar.gz
# # !wget https://storage.googleapis.com/tf_model_garden/vision/movinet/movinet_a5_base_k400.tar.gz

# # !tar -xf movinet_a5_base_k400.tar.gz
# # !mv movinet_a5_base movinet_a5_base_k400
# # !tar -xf movinet_a0_base.tar.gz
# !tar -xf movinet_a3_base.tar.gz
# # !tar -xf movinet_a5_base.tar.gz

# %%
model_version = 'a3'

if model_version=='a3':
  max_frames = 120
  image_dims = (256,256)
elif model_version=='a2':
  max_frames = 50
  image_dims = (224,224)
elif model_version=='a0':
  max_frames = 50
  image_dims = (172,172)

# %%
# # Get the kinetics-600 action labels
# KINETICS_URL = "official/projects/movinet/files/kinetics_600_labels.txt"
# with open(KINETICS_URL) as obj:
#   labels_600 = [line for line in obj.readlines()]
# print("Found %d labels." % len(labels_600))

# %%
# vid1 = pd.read_parquet('s3://asl-capstone/wlasl/video_mappings_masterfile.parquet', 
#                        columns=['word','rgb_path','padded_path'])


# vid2 = pd.read_parquet('s3://asl-capstone/msasl/video_mappings_masterfile.parquet')
# vid2 = vid2.rename(columns={'caption':'word', 'path':'rgb_path'})
# vid2['padded_path'] = vid2.rgb_path.replace('/RGB/', '/padded/')

# video_files = pd.concat([vid1, vid2], axis=0)

# label_nums = video_files.word.value_counts().reset_index().reset_index().rename(columns={'index':'label_num'})

# label_nums.to_parquet('s3://asl-capstone/movinet_word_labels.parquet')

# video_files = video_files.merge(label_nums, on='word')
# video_files = video_files.drop_duplicates()
# video_files['padded_path'] = video_files['padded_path'].str.replace('/RGB/', '/padded/')
# video_files.to_parquet('s3://asl-capstone/movinet_masterfile_mappings.parquet')

# %%
video_files = pd.read_parquet('s3://asl-capstone/movinet_masterfile_mappings.parquet')

# %%
display(video_files.head())
print(video_files.shape)
print(video_files.word.nunique())

# media.show_video(vid, codec='gif', fps=10)
# Out:
#         word                                rgb_path  \
# 0  viewpoint  asl-capstone/wlasl/RGB/viewpoint_0.npy
# 1  viewpoint  asl-capstone/wlasl/RGB/viewpoint_1.npy
# 2  viewpoint  asl-capstone/wlasl/RGB/viewpoint_2.npy
# 3  viewpoint  asl-capstone/wlasl/RGB/viewpoint_3.npy
# 4  viewpoint  asl-capstone/wlasl/RGB/viewpoint_4.npy
#
#                                  padded_path  label_num  count
# 0  asl-capstone/wlasl/padded/viewpoint_0.npy       1387      5
# 1  asl-capstone/wlasl/padded/viewpoint_1.npy       1387      5
# 2  asl-capstone/wlasl/padded/viewpoint_2.npy       1387      5
# 3  asl-capstone/wlasl/padded/viewpoint_3.npy       1387      5
# 4  asl-capstone/wlasl/padded/viewpoint_4.npy       1387      5
# (25479, 5)
# 1997

# %%
video_files[video_files['padded_path'].str.contains('msasl')]

video_files['padded_path'] = video_files['padded_path'].str.replace('/RGB/', '/padded/')

# %%
video_files.word.value_counts()[:10]
# Out:
# word
# africa       72
# afternoon    70
# afraid       54
# again        45
# accident     43
# thin         36
# before       36
# adopt        36
# tall         33
# cousin       33
# Name: count, dtype: int64

# %%
smaller_samples = video_files[video_files['count']<=50]
larger_samples = video_files[video_files['count']>50].groupby('word').sample(50)

video_files = pd.concat([smaller_samples,larger_samples])
video_files.word.value_counts()[:10]
# Out:
# word
# afternoon    50
# africa       50
# afraid       50
# again        45
# accident     43
# thin         36
# adopt        36
# before       36
# tall         33
# cousin       33
# Name: count, dtype: int64

# %%
video_files[video_files['count'] >= 27].word.nunique()
# Out:
# 107

# %%
# count = video_files.word.value_counts()[:200][-1]
# words = video_files.word.value_counts()[video_files.word.value_counts() >= count].reset_index()['word'].unique()

# video_files = video_files[video_files.word.isin(words)]

video_files = video_files[video_files['count'] >= 27]

video_files.shape
# Out:
# (3148, 5)

# %%
NUM_CLASSES = video_files.word.nunique()
NUM_CLASSES
# Out:
# 107

# %%
# print(video_files['frame_count'].mean())
# print(video_files['frame_count'].median())
# print(video_files['frame_count'].max())

# %%
train_files, test_files = train_test_split(video_files, train_size=0.8)
print(train_files.shape)
print(test_files.shape)
# Out:
# (2518, 5)
# (630, 5)

# %%
train_files['flip'] = False

bootstrap = train_files.groupby('word').sample(2)
bootstrap['flip'] = True

train_files = pd.concat([train_files, bootstrap]).sample(frac=1)
train_files.shape
# Out:
# (2732, 6)

# %%
def data_generator(file_paths_df, add_flip=False):
    for _, row in file_paths_df.iterrows():
        with fs.open(row['padded_path'], 'rb') as f:
            video = np.load(f)

        if add_flip:
            if row['flip']==True:
                video = np.flip(video, axis=2)

        video = tf.convert_to_tensor(video)
        #video = pad_video_frames(video, n_frames=n_frames)
        label = tf.one_hot(row['label_num'], NUM_CLASSES)
        yield video, label


# Create TensorFlow Dataset for model input. 
train_dataset = tf.data.Dataset.from_generator(
    generator=lambda: data_generator(train_files, add_flip=True),
    output_signature=(
        tf.TensorSpec(shape=(120, 256, 256, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(NUM_CLASSES), dtype=tf.int32)
    )
)

# Create TensorFlow Dataset for model input. 
test_dataset = tf.data.Dataset.from_generator(
    generator=lambda: data_generator(test_files),
    output_signature=(
        tf.TensorSpec(shape=(120, 256, 256, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(NUM_CLASSES), dtype=tf.int32)
    )
)
# Out:
# 2023-11-27 18:09:45.775913: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:45.796391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:45.797245: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:45.799306: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:45.800072: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:45.800787: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:46.418392: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:46.419350: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:46.420127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 18:09:46.420830: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20591 MB memory:  -> device: 0, name: NVIDIA A10G, pci bus id: 0000:00:1e.0, compute capability: 8.6

# %%
#next(iter(train_dataset.batch(1))) #Does a sanity check to confirm that the dataset is processed in batches

# %%
#from official.projects.movinet.modeling import movinet_model

from official.projects.movinet.modeling import movinet

# Create backbone and model.
backbone = movinet.Movinet(
    model_id=model_version, #change to correspond to model
    causal=False,
    use_external_states=False,
)

# %%
from official.projects.movinet.modeling import movinet_model_modified

def build_classifier(backbone, num_classes, encoder_dim=768):
    """Builds a classifier on top of a backbone model."""
    model = movinet_model_modified.MovinetClassifier(
        backbone=backbone,
        num_classes=num_classes, 
        encoder_dim=encoder_dim)
    model.build([2, 120, 256, 256, 3])

    model.layers[0].trainable = False
    model.layers[1].trainable = True
    model.layers[-1].trainable = True
    
    for i in range(25):
        model.layers[1].layers[i].trainable = False

    model.layers[1].layers[-1].trainable = False

    return model

# Wrap the backbone with a new classifier to create a new classifier head
# with num_classes outputs (101 classes for UCF101).
# Freeze all layers except for the final classifier head.
model = build_classifier(backbone, NUM_CLASSES, encoder_dim=768, dropout_rate=0.05)

# %%
model.summary()
# Out:
# Model: "movinet_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image (InputLayer)          [(None, None, None, Non   0
#                              e, 3)]
#
#  movinet (Movinet)           ({'stem': (None, None,    4688129
#                              None, None, 16),
#                               'block0_layer0': (None
#                              , None, None, None, 16)
#                              , 'block0_layer1': (Non
#                              e, None, None, None, 16
#                              ),
#                               'block0_layer2': (None
#                              , None, None, None, 16)
#                              , 'block0_layer3': (Non
#                              e, None, None, None, 16
#                              ),
#                               'block1_layer0': (None
#                              , None, None, None, 48)
#                              , 'block1_layer1': (Non
#                              e, None, None, None, 48
#                              ),
#                               'block1_layer2': (None
#                              , None, None, None, 48)
#                              , 'block1_layer3': (Non
#                              e, None, None, None, 48
#                              ),
#                               'block1_layer4': (None
#                              , None, None, None, 48)
#                              , 'block1_layer5': (Non
#                              e, None, None, None, 48
#                              ),
#                               'block2_layer0': (None
#                              , None, None, None, 80)
#                              , 'block2_layer1': (Non
#                              e, None, None, None, 80
#                              ),
#                               'block2_layer2': (None
#                              , None, None, None, 80)
#                              , 'block2_layer3': (Non
#                              e, None, None, None, 80
#                              ),
#                               'block2_layer4': (None
#                              , None, None, None, 80)
#                              , 'block3_layer0': (Non
#                              e, None, None, None, 88
#                              ),
#                               'block3_layer1': (None
#                              , None, None, None, 88)
#                              , 'block3_layer2': (Non
#                              e, None, None, None, 88
#                              ),
#                               'block3_layer3': (None
#                              , None, None, None, 88)
#                              , 'block3_layer4': (Non
#                              e, None, None, None, 88
#                              ),
#                               'block3_layer5': (None
#                              , None, None, None, 88)
#                              , 'block3_layer6': (Non
#                              e, None, None, None, 88
#                              ),
#                               'block3_layer7': (None
#                              , None, None, None, 88)
#                              , 'block4_layer0': (Non
#                              e, None, None, None, 16
#                              8),
#                               'block4_layer1': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer2': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer3': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer4': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer5': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer6': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer7': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer8': (None
#                              , None, None, None, 168
#                              ),
#                               'block4_layer9': (None
#                              , None, None, None, 168
#                              ),
#                               'head': (None, None, N
#                              one, None, 744)},
#                               {'state_block0_layer0_
#                              pool_buffer': (None, No
#                              ne, None, None, 40),
#                               'state_block0_layer0_p
#                              ool_frame_count': (1,),
#                               'state_block0_layer1_p
#                              ool_buffer': (None, Non
#                              e, None, None, 40),
#                               'state_block0_layer1_p
#                              ool_frame_count': (1,),
#                               'state_block0_layer2_p
#                              ool_buffer': (None, Non
#                              e, None, None, 64),
#                               'state_block0_layer2_p
#                              ool_frame_count': (1,),
#                               'state_block0_layer3_p
#                              ool_buffer': (None, Non
#                              e, None, None, 40),
#                               'state_block0_layer3_p
#                              ool_frame_count': (1,),
#                               'state_block1_layer0_p
#                              ool_buffer': (None, Non
#                              e, None, None, 112),
#                               'state_block1_layer0_p
#                              ool_frame_count': (1,),
#                               'state_block1_layer1_p
#                              ool_buffer': (None, Non
#                              e, None, None, 144),
#                               'state_block1_layer1_p
#                              ool_frame_count': (1,),
#                               'state_block1_layer2_p
#                              ool_buffer': (None, Non
#                              e, None, None, 112),
#                               'state_block1_layer2_p
#                              ool_frame_count': (1,),
#                               'state_block1_layer3_p
#                              ool_buffer': (None, Non
#                              e, None, None, 112),
#                               'state_block1_layer3_p
#                              ool_frame_count': (1,),
#                               'state_block1_layer4_p
#                              ool_buffer': (None, Non
#                              e, None, None, 144),
#                               'state_block1_layer4_p
#                              ool_frame_count': (1,),
#                               'state_block1_layer5_p
#                              ool_buffer': (None, Non
#                              e, None, None, 144),
#                               'state_block1_layer5_p
#                              ool_frame_count': (1,),
#                               'state_block2_layer0_p
#                              ool_buffer': (None, Non
#                              e, None, None, 240),
#                               'state_block2_layer0_p
#                              ool_frame_count': (1,),
#                               'state_block2_layer1_p
#                              ool_buffer': (None, Non
#                              e, None, None, 152),
#                               'state_block2_layer1_p
#                              ool_frame_count': (1,),
#                               'state_block2_layer2_p
#                              ool_buffer': (None, Non
#                              e, None, None, 240),
#                               'state_block2_layer2_p
#                              ool_frame_count': (1,),
#                               'state_block2_layer3_p
#                              ool_buffer': (None, Non
#                              e, None, None, 192),
#                               'state_block2_layer3_p
#                              ool_frame_count': (1,),
#                               'state_block2_layer4_p
#                              ool_buffer': (None, Non
#                              e, None, None, 240),
#                               'state_block2_layer4_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer0_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer0_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer1_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer1_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer2_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer2_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer3_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer3_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer4_p
#                              ool_buffer': (None, Non
#                              e, None, None, 160),
#                               'state_block3_layer4_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer5_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer5_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer6_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer6_p
#                              ool_frame_count': (1,),
#                               'state_block3_layer7_p
#                              ool_buffer': (None, Non
#                              e, None, None, 264),
#                               'state_block3_layer7_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer0_p
#                              ool_buffer': (None, Non
#                              e, None, None, 560),
#                               'state_block4_layer0_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer1_p
#                              ool_buffer': (None, Non
#                              e, None, None, 448),
#                               'state_block4_layer1_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer2_p
#                              ool_buffer': (None, Non
#                              e, None, None, 448),
#                               'state_block4_layer2_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer3_p
#                              ool_buffer': (None, Non
#                              e, None, None, 560),
#                               'state_block4_layer3_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer4_p
#                              ool_buffer': (None, Non
#                              e, None, None, 560),
#                               'state_block4_layer4_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer5_p
#                              ool_buffer': (None, Non
#                              e, None, None, 560),
#                               'state_block4_layer5_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer6_p
#                              ool_buffer': (None, Non
#                              e, None, None, 448),
#                               'state_block4_layer6_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer7_p
#                              ool_buffer': (None, Non
#                              e, None, None, 448),
#                               'state_block4_layer7_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer8_p
#                              ool_buffer': (None, Non
#                              e, None, None, 560),
#                               'state_block4_layer8_p
#                              ool_frame_count': (1,),
#                               'state_block4_layer9_p
#                              ool_buffer': (None, Non
#                              e, None, None, 672),
#                               'state_block4_layer9_p
#                              ool_frame_count': (1,),
#                               'state_head_pool_buffe
#                              r': (None, None, None,
#                              None, 744),
#                               'state_head_pool_frame
#                              _count': (1,)})
#
#  classifier_head (Classifie  ((None, 107),             114587
#  rHead)                       (None, None, 768))
#
# =================================================================
# Total params: 4802716 (18.32 MB)
# Trainable params: 3452525 (13.17 MB)
# Non-trainable params: 1350191 (5.15 MB)
# _________________________________________________________________

# %%
for i in range(len(model.layers[1].layers)):
    print(model.layers[1].layers[i].name, i, model.layers[1].layers[i].trainable)
# Out:
# inputs 0 False
# stem 1 False
# block0_layer0 2 False
# block0_layer1 3 False
# block0_layer2 4 False
# block0_layer3 5 False
# block1_layer0 6 False
# block1_layer1 7 False
# block1_layer2 8 False
# block1_layer3 9 False
# block1_layer4 10 False
# block1_layer5 11 False
# block2_layer0 12 False
# block2_layer1 13 False
# block2_layer2 14 False
# block2_layer3 15 False
# block2_layer4 16 False
# block3_layer0 17 False
# block3_layer1 18 False
# block3_layer2 19 False
# block3_layer3 20 False
# block3_layer4 21 False
# block3_layer5 22 False
# block3_layer6 23 False
# block3_layer7 24 False
# block4_layer0 25 True
# block4_layer1 26 True
# block4_layer2 27 True
# block4_layer3 28 True
# block4_layer4 29 True
# block4_layer5 30 True
# block4_layer6 31 True
# block4_layer7 32 True
# block4_layer8 33 True
# block4_layer9 34 True
# head 35 False

# %%
# import tensorflow_model_optimization as tfmot

# # q_aware stands for for quantization aware.
# q_aware_model = tfmot.quantization.keras.quantize_apply(model)


# Dense layers should be quantized.
# def apply_quantization_to_dense(layer):
#   if isinstance(layer, tf.keras.layers.Dense):
#     return tfmot.quantization.keras.quantize_annotate_layer(layer)
#   return layer

# # Use `tf.keras.models.clone_model` to apply `apply_quantization_to_dense` 
# # to the layers of the model.
# annotated_model = tf.keras.models.clone_model(
#     base_model,
#     clone_function=apply_quantization_to_dense,
# )

# # Now that the Dense layers are annotated,
# # `quantize_apply` actually makes the model quantization aware.
# quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model)

# quant_aware_model.summary()

# %%
NUM_EPOCHS = 2
BATCH_SIZE = 10

train_steps = len(train_files) // BATCH_SIZE
total_train_steps = train_steps * NUM_EPOCHS

test_steps = len(test_files) // BATCH_SIZE

loss_obj = tf_keras.losses.CategoricalCrossentropy(
    from_logits=True, #label_smoothing=0.05
    )

metrics = [
    tf_keras.metrics.TopKCategoricalAccuracy(
        k=1, name='top_1', dtype=tf.float32),
    tf_keras.metrics.TopKCategoricalAccuracy(
        k=5, name='top_5', dtype=tf.float32),
]

initial_learning_rate = 0.001
learning_rate = tf_keras.optimizers.schedules.CosineDecay(
    initial_learning_rate, decay_steps=total_train_steps, warmup_target=0.01, warmup_steps=4
)

optimizer = tf_keras.optimizers.RMSprop(learning_rate=learning_rate,
                                        rho=0.9, momentum=0.9, 
                                        epsilon=1.0, clipnorm=1.0)


model.compile(loss={'prediction':loss_obj, 'vid_embedding':None}, 
              optimizer=optimizer, 
              metrics={'prediction':metrics, 'vid_embedding':None})


# look into quantization for tf

# %%
# %matplotlib inline

def visualize_lr_schedule(opt, n_steps, step_s) -> Tuple[List[int], List[float]]:
    """Visualize tensorflow keras scheduler learning rate over the course of n_steps training steps.

    Args:
        opt (LearningRateSchedule): learning rate scheduler to be visualized.
        n_steps (int): number of training steps to visualize over.
        step_s (int): sampling step of the training steps, i.e. takes each step_s in the interval [0, n_steps].

    Returns:
        Tuple[List[int], List[float]]: returns x (steps), y (lr values) values of the plot.
    """
    lr = []
    steps = list(range(0, n_steps, step_s))

    for step in steps:
        lr_at_s = opt(step).numpy()
        lr.append(lr_at_s)

    plt.suptitle(f'Learning rate schedule of {type(opt).__name__}')
    plt.plot(steps, lr)

    return steps, lr


steps, lr_values = visualize_lr_schedule(learning_rate, n_steps=total_train_steps, step_s=1)

# %%
results = model.fit(
                train_dataset.batch(BATCH_SIZE, drop_remainder=True), #14, lr = 0.001, RMSprop, bootstrapping, 56 classes
                validation_data=test_dataset.batch(BATCH_SIZE, drop_remainder=True),
                epochs=NUM_EPOCHS,
                # steps_per_epoch=train_steps,
                # validation_steps=test_steps,
                verbose=1)

# Epoch 1
# 103/103 7429s 71s/step - loss: 5.7013 - classifier_head_loss: 5.7013 - classifier_head_top_1: 0.0206 - classifier_head_top_5: 0.1214 - val_loss: 1163.0439 - val_classifier_head_loss: 1163.0439 - val_classifier_head_top_1: 0.0147 - val_classifier_head_top_5: 1.0000


# Epoch 1 partial, 696 classes (with counts >20)
# 149/Unknown - 8534s 56s/step - loss: 6.7610 - classifier_head_loss: 6.7610 - classifier_head_top_1: 0.0034 - classifier_head_top_5: 0.0084
# Out:
# Epoch 1/2
# 2023-11-27 18:13:09.006704: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1f8b1f00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-27 18:13:09.006737: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# 2023-11-27 18:13:10.081015: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8903
# 2023-11-27 18:13:14.523597: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-11-27 18:13:57.774418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-27 18:13:58.054730: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.80GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-11-27 18:13:58.069113: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#       5/Unknown - 495s 69s/step - loss: 5.6013 - classifier_head_loss: 5.6013 - classifier_head_top_1: 0.0000e+00 - classifier_head_top_5: 0.0200

# %%
model.save('/home/ec2-user/ASL-Translator/modeling/movinet_checkpoints')
# Out:
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f075c1f9ba0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074feeeb90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f6bb5e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f62f040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f075c074160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f464c40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fa2d210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f889900>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fff8280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f902a70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f7ba8c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fe88be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fd55d80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fb3cf40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fa89cf0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fc64a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f77cf40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f8b01f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f456e90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fac35e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074fa68d00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f4423e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074f518370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074ee06800>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074eeac370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074ed7cd30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074ec2ea40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074ecdfe80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074ebbbb20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074ea62b30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074e91bc70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074e9f0eb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of TF-Keras layer <official.vision.modeling.layers.nn_layers.SpatialAveragePool3D object at 0x7f074e8b2980>, because it is not built.
# INFO:tensorflow:Assets written to: /home/ec2-user/ASL-Translator/modeling/movinet_checkpoints/assets
# INFO:tensorflow:Assets written to: /home/ec2-user/ASL-Translator/modeling/movinet_checkpoints/assets

# %%
checkpoint = tf.train.Checkpoint(model)
path_saving = checkpoint.save('/tmp/training_checkpoints')

# %%
def get_instance_id():
    """Get current instance ID from metadata"""
    url = "http://169.254.169.254/latest/meta-data/instance-id"
    response = requests.get(url)
    return response.text

def stop_instance(instance_id, region_name='us-west-2'):
    """Stop the EC2 instance"""
    ec2 = boto3.client('ec2', aws_access_key_id = aws_access_key_id, aws_secret_access_key = aws_secret_access_key, region_name=region_name)
    ec2.stop_instances(InstanceIds=[instance_id])

# %%
# Get the current instance ID
instance_id = get_instance_id()
print(instance_id)
# Stop the instance
stop_instance(instance_id)

# %%
results = model.fit(
                train_dataset.batch(BATCH_SIZE), #14, lr = 0.001, Adafactor, 656 classes
                validation_data=test_dataset.batch(BATCH_SIZE),
                epochs=NUM_EPOCHS,
                steps_per_epoch=train_steps,
                validation_steps=test_steps,
                verbose=1)

# 14/268 ETA: 7:43:44 - loss: 2.0779 - classifier_head_loss: 2.0779 - classifier_head_top_1: 0.0051 - classifier_head_top_5: 0.0204
# Out:
#  14/268 [>.............................] - ETA: 7:43:44 - loss: 2.0779 - classifier_head_loss: 2.0779 - classifier_head_top_1: 0.0051 - classifier_head_top_5: 0.0204

# %%
results = model.fit(
                train_dataset.batch(BATCH_SIZE), #12, lr = 0.01, adafactor, 656 classes
                validation_data=test_dataset.batch(BATCH_SIZE),
                epochs=NUM_EPOCHS,
                steps_per_epoch=train_steps,
                validation_steps=test_steps,
                verbose=1)

# 313/313 - ETA: 0s - loss: 5.5397 - classifier_head_loss: 5.5397 - classifier_head_top_1: 0.0013 - classifier_head_top_5: 0.0077
# Out:
# 2023-11-20 17:03:26.068579: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1f8be1b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-20 17:03:26.068629: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# 2023-11-20 17:03:29.061197: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8903
# 2023-11-20 17:03:36.363940: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-11-20 17:04:24.872884: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-20 17:04:24.910181: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 313/313 [==============================] - ETA: 0s - loss: 5.5397 - classifier_head_loss: 5.5397 - classifier_head_top_1: 0.0013 - classifier_head_top_5: 0.0077
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 results = model.fit(
#       2                 train_dataset.batch(BATCH_SIZE), #12, lr = 0.01
#       3                 validation_data=test_dataset.batch(BATCH_SIZE),
#       4                 epochs=NUM_EPOCHS,
#       5                 steps_per_epoch=train_steps,
#       6                 validation_steps=test_steps,
#       7                 verbose=1)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tf_keras/src/engine/training.py:1853, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1837 if getattr(self, "_eval_data_handler", None) is None:
#    1838     self._eval_data_handler = data_adapter.get_data_handler(
#    1839         x=val_x,
#    1840         y=val_y,
#    (...)
#    1851         pss_evaluation_shards=self._pss_evaluation_shards,
#    1852     )
# -> 1853 val_logs = self.evaluate(
#    1854     x=val_x,
#    1855     y=val_y,
#    1856     sample_weight=val_sample_weight,
#    1857     batch_size=validation_batch_size or batch_size,
#    1858     steps=validation_steps,
#    1859     callbacks=callbacks,
#    1860     max_queue_size=max_queue_size,
#    1861     workers=workers,
#    1862     use_multiprocessing=use_multiprocessing,
#    1863     return_dict=True,
#    1864     _use_cached_eval_dataset=True,
#    1865 )
#    1866 val_logs = {
#    1867     "val_" + name: val for name, val in val_logs.items()
#    1868 }
#    1869 epoch_logs.update(val_logs)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tf_keras/src/engine/training.py:2292, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2288             with tf.profiler.experimental.Trace(
#    2289                 "test", step_num=step, _r=1
#    2290             ):
#    2291                 callbacks.on_test_batch_begin(step)
# -> 2292                 logs = test_function_runner.run_step(
#    2293                     dataset_or_iterator,
#    2294                     data_handler,
#    2295                     step,
#    2296                     self._pss_evaluation_shards,
#    2297                 )
#    2299 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2300 # Override with model metrics instead of last step logs
#
# File /opt/tensorflow/lib/python3.10/site-packages/tf_keras/src/engine/training.py:4100, in _TestFunction.run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4099 def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4100     tmp_logs = self._function(dataset_or_iterator)
#    4101     if data_handler.should_sync:
#    4102         context.async_wait()
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:864, in Function._call(self, *args, **kwds)
#     861 self._lock.release()
#     862 # In this case we have not created variables on the first call. So we can
#     863 # run the first trace but we should fail if variables are created.
# --> 864 results = self._variable_creation_fn(*args, **kwds)
#     865 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     866   raise ValueError("Creating variables on a non-first call to a function"
#     867                    " decorated with tf.function.")
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File /opt/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# with tf.device("/GPU:0"):
results = model.fit(
                train_dataset.batch(BATCH_SIZE), #12, lr = 0.1, adafactor, 2000 classes
                validation_data=test_dataset.batch(BATCH_SIZE),
                epochs=NUM_EPOCHS,
                steps_per_epoch=train_steps,
                validation_steps=test_steps,
                verbose=1)
    
# results = q_aware_model.fit(
#                 train_dataset.batch(BATCH_SIZE),
#                 validation_data=test_dataset.batch(BATCH_SIZE),
#                 epochs=NUM_EPOCHS,
#                 steps_per_epoch=train_steps,
#                 validation_steps=test_steps,
#                 verbose=1)

# 122/313 - ETA: 4:38:20 - loss: 5.8746 - classifier_head_loss: 5.8746 - classifier_head_top_1: 6.8306e-04 - classifier_head_top_5: 0.0027
# Out:
# 2023-11-20 03:25:05.520218: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x20fa2680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-20 03:25:05.520269: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# 2023-11-20 03:25:06.600233: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8903
# 2023-11-20 03:25:11.734728: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-11-20 03:26:00.069649: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-20 03:26:00.080313: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 122/313 [==========>...................] - ETA: 4:38:20 - loss: 5.8746 - classifier_head_loss: 5.8746 - classifier_head_top_1: 6.8306e-04 - classifier_head_top_5: 0.0027

# %% [raw]
# - Increase number of epochs
# - Increase the batch size
# - Do a stratified train-val-test-split
# - Save embeddings as a checkpoint in such a way that it is trainable
# - Try adding additional dense layers
# - Try training a couple layers into the backbone
